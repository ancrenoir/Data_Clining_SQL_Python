# %%
import pandas as pd

# %%
file_excel = 'C:/APPRENDRE_DATA_ANALYSE_WITH_ALEX/PROJET_PORTEFOLIO/Projet_data_clining/Nashville Housing Data for Data Cleaning.xlsx'

# %%
chemin_csv = 'C:/APPRENDRE_DATA_ANALYSE_WITH_ALEX/PROJET_PORTEFOLIO/Projet_data_clining/Nashville Housing Data for Data Cleaning.csv'

# %%
 data_excel= pd.read_excel(file_excel)

# %%
data_excel.to_csv(chemin_csv, index = False)

# %%
data_excel.head(100)
# Out:
#     UniqueID          ParcelID        LandUse  \
# 0        2045  007 00 0 125.00  SINGLE FAMILY
# 1       16918  007 00 0 130.00  SINGLE FAMILY
# 2       54582  007 00 0 138.00  SINGLE FAMILY
# 3       43070  007 00 0 143.00  SINGLE FAMILY
# 4       22714  007 00 0 149.00  SINGLE FAMILY
# ..        ...              ...            ...
# 95      28157  018 08 0 025.00  SINGLE FAMILY
# 96      46861  018 11 0 005.00  SINGLE FAMILY
# 97      14426  018 11 0 015.00  SINGLE FAMILY
# 98      40658  018 11 0 024.00  SINGLE FAMILY
# 99      18370  018 12 0 009.00  SINGLE FAMILY
#
#                        PropertyAddress   SaleDate  SalePrice  \
# 0   1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1   1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2   1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 3   1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000
# 4   1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000
# ...

# %%
type_data = [x.dtype for x ]
# Out:
# datetime64[ns]

# %%
liste_columns = [x for x in data_excel]
# Out:
# 0

# %%
# Out:
#   File <string>:4
#     return a = z
#                 ^
# IndentationError: unindent does not match any outer indentation level

# %%
data_excel.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate',
#        'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName',
#        'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue',
#        'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
data_excel.head(10)
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
# 5      18367  007 00 0 151.00  SINGLE FAMILY
# 6      19804  007 14 0 002.00  SINGLE FAMILY
# 7      54583  007 14 0 024.00  SINGLE FAMILY
# 8      36500  007 14 0 026.00  SINGLE FAMILY
# 9      19805  007 14 0 034.00  SINGLE FAMILY
#
#                          PropertyAddress   SaleDate  SalePrice  \
# 0     1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1     1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2     1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 3     1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000
# 4     1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000
# 5     1821  FOX CHASE DR, GOODLETTSVILLE 2014-07-16     267000
# ...
