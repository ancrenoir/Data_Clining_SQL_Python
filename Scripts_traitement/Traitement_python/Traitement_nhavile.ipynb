# %% [markdown]
#  #### Le but de ce fichier .ipynb est de traiter en ammont la base de données "Nasville Houssing Data Cleaning" pour importation sans erreurs dans mysql pour le netoyage ulterrieur des données

# %%
import pandas as pd

# %%
file_excel = 'C:/APPRENDRE_DATA_ANALYSE_WITH_ALEX/PROJET_PORTEFOLIO/Projet_data_clining/Nashville Housing Data for Data Cleaning.xlsx'

# %%
chemin_csv1 = 'C:/APPRENDRE_DATA_ANALYSE_WITH_ALEX/PROJET_PORTEFOLIO/Projet_data_clining/Nashville Housing Data for Data Cleaning1.csv'

# %%
/// Utilisation de la bibliotechque pandas pour importation de la base de donnée sous les deux formats ('csv', 'excel')

# %%
data_excel= pd.read_excel(file_excel)

# %%
data_csv = pd.read_csv(chemin_csv)

# %%
///

# %%
data_csv = data_csv.drop('Unnamed: 0', axis = 1)

# %%
data_csv.head(20)
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       18367   007 00 0 151.00      SINGLE FAMILY
# 6       19804   007 14 0 002.00      SINGLE FAMILY
# 7       54583   007 14 0 024.00      SINGLE FAMILY
# 8       36500   007 14 0 026.00      SINGLE FAMILY
# 9       19805   007 14 0 034.00      SINGLE FAMILY
# 10      29467  007 14 0A 024.00      SINGLE FAMILY
# 11      10754  007 14 0A 027.00      SINGLE FAMILY
# 12      34751  007 14 0B 010.00  RESIDENTIAL CONDO
# 13       4512   007 15 0 002.00      SINGLE FAMILY
# 14      16919   007 15 0 003.00      SINGLE FAMILY
# 15      16920   007 15 0 004.00      SINGLE FAMILY
# 16      51967   007 15 0 008.00      SINGLE FAMILY
# ...

# %%
data_excel.head(20)
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       18367   007 00 0 151.00      SINGLE FAMILY
# 6       19804   007 14 0 002.00      SINGLE FAMILY
# 7       54583   007 14 0 024.00      SINGLE FAMILY
# 8       36500   007 14 0 026.00      SINGLE FAMILY
# 9       19805   007 14 0 034.00      SINGLE FAMILY
# 10      29467  007 14 0A 024.00      SINGLE FAMILY
# 11      10754  007 14 0A 027.00      SINGLE FAMILY
# 12      34751  007 14 0B 010.00  RESIDENTIAL CONDO
# 13       4512   007 15 0 002.00      SINGLE FAMILY
# 14      16919   007 15 0 003.00      SINGLE FAMILY
# 15      16920   007 15 0 004.00      SINGLE FAMILY
# 16      51967   007 15 0 008.00      SINGLE FAMILY
# ...

# %%
print(data_excel['SaleDate'].dtypes)
# Out:
# datetime64[ns]

# %%
/// Verification si la totalité des données on été importées

# %%
data_excel.shape
data_csv.shape
# Out:
# (56477, 19)

# %%
fonction type_columns retournant un dictionaire ayant pour clé les colonnes de dataframe et valeurs le type de données de la dataframe

# %%
def type_columns(Data,X):
    data_type = {}
    for x in X:
        data_type[x]= Data[x].dtype
    return data_type

# %%
type_columns(data_excel, list_columns)
# Out:
# {'UniqueID ': dtype('int64'),
#  'ParcelID': dtype('O'),
#  'LandUse': dtype('O'),
#  'PropertyAddress': dtype('O'),
#  'SaleDate': dtype('<M8[ns]'),
#  'SalePrice': dtype('int64'),
#  'LegalReference': dtype('O'),
#  'SoldAsVacant': dtype('O'),
#  'OwnerName': dtype('O'),
#  'OwnerAddress': dtype('O'),
#  'Acreage': dtype('float64'),
#  'TaxDistrict': dtype('O'),
#  'LandValue': dtype('float64'),
#  'BuildingValue': dtype('float64'),
#  'TotalValue': dtype('float64'),
#  'YearBuilt': dtype('float64'),
#  'Bedrooms': dtype('float64'),
#  'FullBath': dtype('float64'),
#  'HalfBath': dtype('float64')}

# %%
Boucle permettant de remplacer les valeurs manquante, NaN, par la string 0

# %%
for X in list_columns:
    data_csv[X]= data_csv[X].apply(lambda x : '0' if pd.isna(x) else x)

# %%
Boucle permettant unification du type des colonne de la base de données

# %%
for X in list_columns:
    data_csv[X]=data_csv[X].astype(data_csv[X].dtype)

# %%
/// Sauvegarde de la base de donnée (.csv) sans index associé par pandas à la dataframe

# %%
data_csv.to_csv(chemin_csv1, index = False)

# %%
data_csv['Acreage']=data_csv['Acreage'].astype('float64')
